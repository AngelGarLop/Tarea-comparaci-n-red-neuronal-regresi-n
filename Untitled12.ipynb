# %%
#!pip install scikeras

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import kagglehub
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
import keras_tuner as kt

# %% [markdown]
# Cargamos el dataframe

# %%
path = kagglehub.dataset_download("yasserh/walmart-dataset")
df_walmart = pd.read_csv(path+"/Walmart.csv")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.10).

# %% [markdown]
# Vemos la columnas que tiene y los datos de ellas

# %%
df_walmart.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df_walmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df_walmart.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df_walmart.Weekly_Sales.mean()/45
# Out:
# 23265.886168039367

# %%
def describe_columna(df, col):
    print(f'Columna: {col}  -  Tipo de datos: {df[col].dtype}')
    print(f'Número de valores nulos: {df[col].isnull().sum()}  -  Número de valores distintos: {df[col].nunique()}')
    print('Valores más frecuentes:')
    for i, v in df[col].value_counts().iloc[:10].items() :
        print(i, '\t', v)

# %%
describe_columna(df_walmart, 'Store')
# Out:
# Columna: Store  -  Tipo de datos: int64
# Número de valores nulos: 0  -  Número de valores distintos: 45
# Valores más frecuentes:
# 1 	 143
# 24 	 143
# 26 	 143
# 27 	 143
# 28 	 143
# 29 	 143
# 30 	 143
# 31 	 143
# 32 	 143
# 33 	 143

# %% [markdown]
# Como se ve en el describe anterior tenemos 45 tiendas en las que todas tienen datos de las 143 semanas

# %%
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')
describe_columna(df_walmart, 'Date')

print("\nFecha minima: "+str(df_walmart.Date.min()))
print("\nFecha máxima: "+str(df_walmart.Date.max()))
# Out:
# Columna: Date  -  Tipo de datos: datetime64[ns]
# Número de valores nulos: 0  -  Número de valores distintos: 143
# Valores más frecuentes:
# 2010-02-05 00:00:00 	 45
# 2011-12-23 00:00:00 	 45
# 2011-11-11 00:00:00 	 45
# 2011-11-18 00:00:00 	 45
# 2011-11-25 00:00:00 	 45
# 2011-12-02 00:00:00 	 45
# 2011-12-09 00:00:00 	 45
# 2011-12-16 00:00:00 	 45
# 2011-12-30 00:00:00 	 45
# 2011-10-28 00:00:00 	 45
#
# Fecha minima: 2010-02-05 00:00:00
#
# Fecha máxima: 2012-10-26 00:00:00

# %% [markdown]
# Como se ve claramente  tenemos 45 tiendas por lo que las fechas aparecen 45 veces, tambien tenemos la primera fecha que es 2010-02-05 00:00:00 y la última que es 2012-10-26 00:00:00

# %%
describe_columna(df_walmart, 'Weekly_Sales')
# Out:
# Columna: Weekly_Sales  -  Tipo de datos: float64
# Número de valores nulos: 0  -  Número de valores distintos: 6435
# Valores más frecuentes:
# 1643690.9 	 1
# 446751.45 	 1
# 1332261.01 	 1
# 1366193.35 	 1
# 1384870.51 	 1
# 1344354.41 	 1
# 1473386.75 	 1
# 1543947.23 	 1
# 1469252.05 	 1
# 439424.5 	 1

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["Weekly_Sales"], color="blue")
plt.title("Weekly_Sales")
plt.xlabel("Weekly_Sales")
plt.ylabel("Frecuencia")
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# Como se ve en la grafica, la mayoría de las tienadas venden entre 500000$ y 2000000$, hay alguna que ha llegado a vender 3500000$ que eso corresponderá a periodos de alta venta como black friday o navidad. Esta columna la exploraremos más exhaustivamente más adelante

# %%
describe_columna(df_walmart, 'Holiday_Flag')
# Out:
# Columna: Holiday_Flag  -  Tipo de datos: int64
# Número de valores nulos: 0  -  Número de valores distintos: 2
# Valores más frecuentes:
# 0 	 5985
# 1 	 450

# %% [markdown]
# Aquí se ve que hay más semanas que no son vacacaciones que las que sí lo son, 5985 normales y 450 de vacaciones

# %%
df_walmart['Temperature'] = (df_walmart['Temperature'] - 32) * 5.0/9.0
df_walmart['Temperature'].mean()
describe_columna(df_walmart, 'Temperature')
# Out:
# Columna: Temperature  -  Tipo de datos: float64
# Número de valores nulos: 0  -  Número de valores distintos: 3528
# Valores más frecuentes:
# 10.238888888888889 	 11
# 19.92777777777778 	 10
# 24.81666666666667 	 9
# 24.461111111111112 	 9
# 21.266666666666666 	 9
# 22.56666666666667 	 9
# 10.311111111111112 	 8
# 17.89444444444444 	 8
# 17.805555555555557 	 8
# 25.816666666666666 	 7

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["Temperature"], kde=True, color="blue")
plt.title("Temperature")
plt.xlabel("Temperature")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Aqí hemos pasado la temperatura a grados y se ve que la temperatura más común en es 10 grados y que la mayoría de las temperaturas están sobre 20 y tantos grados

# %%
describe_columna(df_walmart, 'Fuel_Price')
# Out:
# Columna: Fuel_Price  -  Tipo de datos: float64
# Número de valores nulos: 0  -  Número de valores distintos: 892
# Valores más frecuentes:
# 3.638 	 39
# 3.63 	 34
# 2.771 	 29
# 3.891 	 29
# 3.524 	 28
# 2.72 	 28
# 3.594 	 28
# 3.523 	 27
# 3.666 	 27
# 3.129 	 25

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["Fuel_Price"], color="blue")
plt.title("Fuel_Price")
plt.xlabel("Fuel_Price")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Gráfico de línea del fuel a lo largo del tiempo
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_walmart, x="Date", y="Fuel_Price")
plt.title("Precio del fuel a lo largo del tiempo")
plt.xlabel("Fecha")
plt.ylabel("Fuel_Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Aquí se ve que la maypría de semanas el precio de la gasolina ha estado sobre 3.75 que durante todos los años ha esdo subiendo

# %%
describe_columna(df_walmart, 'CPI')
# Out:
# Columna: CPI  -  Tipo de datos: float64
# Número de valores nulos: 0  -  Número de valores distintos: 2145
# Valores más frecuentes:
# 130.5502069 	 11
# 129.0432 	 11
# 127.5800323 	 11
# 127.4404839 	 11
# 127.3009355 	 11
# 127.1917742 	 11
# 127.0876774 	 11
# 126.9835806 	 11
# 126.8794839 	 11
# 126.7934 	 11

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["CPI"], color="blue")
plt.title("CPI")
plt.xlabel("CPI")
plt.ylabel("Frecuencia")
plt.show()

# %%
df_walmart.CPI.describe()
# Out:
# count    6435.000000
# mean      171.578394
# std        39.356712
# min       126.064000
# 25%       131.735000
# 50%       182.616521
# 75%       212.743293
# max       227.232807
# Name: CPI, dtype: float64

# %%
# Gráfico de línea del fuel a lo largo del tiempo
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_walmart, x="Date", y="CPI")
plt.title("Precio del fuel a lo largo del tiempo")
plt.xlabel("Fecha")
plt.ylabel("Fuel_Price")
plt.xticks(rotation=45)
plt.show()

# %%
# Extraer el año de la columna 'date'
df_walmart['Year'] = df_walmart['Date'].dt.year

# Calcular el CPI promedio por año
cpi_por_ano = df_walmart.groupby('Year')['CPI'].mean()

# Mostrar el CPI promedio por año
print(cpi_por_ano)
# Out:
# Year
# 2010    168.101782
# 2011    171.545716
# 2012    175.498781
# Name: CPI, dtype: float64

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["CPI"], kde=True, color="blue")
plt.title("CPI")
plt.xlabel("CPI")
plt.ylabel("Frecuencia")
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Gráfico de línea del CPI a lo largo del tiempo
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_walmart, x="Date", y="CPI")
plt.title("CPI a lo largo del tiempo")
plt.xlabel("Fecha")
plt.ylabel("CPI")
plt.xticks(rotation=45)
plt.show()

# %%
describe_columna(df_walmart, 'Unemployment')
# Out:
# Columna: Unemployment  -  Tipo de datos: float64
# Número de valores nulos: 0  -  Número de valores distintos: 349
# Valores más frecuentes:
# 8.099 	 78
# 8.163 	 56
# 7.852 	 56
# 8.2 	 52
# 6.565 	 52
# 6.891 	 52
# 7.057 	 52
# 7.441 	 52
# 7.931 	 52
# 7.343 	 50

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["Unemployment"], color="blue")
plt.title("Unemployment")
plt.xlabel("Unemployment")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Gráfico de línea del Unemployment a lo largo del tiempo
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_walmart, x="Date", y="Unemployment")
plt.title("Unemployment a lo largo del tiempo")
plt.xlabel("Fecha")
plt.ylabel("Unemployment")
plt.xticks(rotation=45)
plt.show()

# %%
# Histograma de la variable objetivo
plt.figure(figsize=(8, 6))
sns.histplot(df_walmart["Weekly_Sales"], kde=True, color="blue")
plt.title("Ganancias de de wlamart por semanas")
plt.xlabel("Ganancias")
plt.ylabel("Frecuencia")
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# https://stock.walmart.com/_assets/_dcdf462278b22c3409a9ac211937e78c/walmart/db/950/9637/annual_report/2010-annual-report-for-walmart-stores-inc_130221021765802161-%281%29.pdf

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear nuevas columnas 'Year', 'Month' y 'Day'
df_walmart['Year'] = df_walmart['Date'].dt.year
df_walmart['Month'] = df_walmart['Date'].dt.month
df_walmart['Day'] = df_walmart['Date'].dt.day
# Eliminar la columna 'Date'

# %%
# Mapa de calor de correlaciones
plt.figure(figsize=(10, 6))
corr_matrix = df_walmart.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación entre Variables")
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear una columna 'Month' a partir de la columna 'Date'
df_walmart['Month'] = df_walmart['Date'].dt.to_period('M')

# Agrupar por mes y calcular la media de las ventas semanales
df_monthly = df_walmart.groupby('Month').agg({'Weekly_Sales': 'mean'}).reset_index()

# Gráfico lineal de las ventas semanales promedio por mes
plt.figure(figsize=(8, 6))
sns.lineplot(x=df_monthly["Month"].astype(str), y=df_monthly["Weekly_Sales"], alpha=0.5)
plt.title("Ventas Semanales Promedio por Mes")
plt.xlabel("Mes")
plt.ylabel("Ventas Semanales Promedio")
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear una columna 'Month' a partir de la columna 'Date'
df_walmart['Month'] = df_walmart['Date'].dt.to_period('M')

# Gráfico de dispersión de las ventas semanales vs Fuel Price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_walmart, x="Fuel_Price", y="Weekly_Sales", alpha=0.5)
plt.title("Comparación de Ventas Semanales con Fuel Price")
plt.xlabel("Fuel Price")
plt.ylabel("Ventas Semanales")
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear una columna 'Month' a partir de la columna 'Date'
df_walmart['Month'] = df_walmart['Date'].dt.to_period('M')

# Gráfico de caja del número de tiendas vs ventas semanales
plt.figure(figsize=(14, 8))
sns.boxplot(data=df_walmart, x="Store", y="Weekly_Sales")
plt.title("Distribución de Ventas Semanales por Tienda")
plt.xlabel("Número de Tiendas")
plt.ylabel("Ventas Semanales")
plt.xticks(rotation=90)
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Agrupar por tienda y sumar las ventas semanales
total_sales_store = df_walmart.groupby('Store')['Weekly_Sales'].sum().reset_index()

# Ordenar por ventas totales
total_sales_store_sorted = total_sales_store.sort_values(by='Weekly_Sales', ascending=False)

# Mostrar los resultados por tienda
print("Ventas totales por tienda:")
print(total_sales_store_sorted)
# Out:
# Ventas totales por tienda:
#     Store  Weekly_Sales
# 19     20  3.013978e+08
# 3       4  2.995440e+08
# 13     14  2.889999e+08
# 12     13  2.865177e+08
# 1       2  2.753824e+08
# 9      10  2.716177e+08
# 26     27  2.538559e+08
# 5       6  2.237561e+08
# 0       1  2.224028e+08
# 38     39  2.074455e+08
# 18     19  2.066349e+08
# 30     31  1.996139e+08
# 22     23  1.987506e+08
# 23     24  1.940160e+08
# 10     11  1.939628e+08
# 27     28  1.892637e+08
# 40     41  1.813419e+08
# 31     32  1.668192e+08
# 17     18  1.551147e+08
# 21     22  1.470756e+08
# 11     12  1.442872e+08
# 25     26  1.434164e+08
# 33     34  1.382498e+08
# 39     40  1.378703e+08
# 34     35  1.315207e+08
# 7       8  1.299512e+08
# 16     17  1.277821e+08
# 44     45  1.123953e+08
# 20     21  1.081179e+08
# 24     25  1.010612e+08
# 42     43  9.056544e+07
# 14     15  8.913368e+07
# 6       7  8.159828e+07
# 41     42  7.956575e+07
# 8       9  7.778922e+07
# 28     29  7.714155e+07
# 15     16  7.425243e+07
# 36     37  7.420274e+07
# 29     30  6.271689e+07
# 2       3  5.758674e+07
# 37     38  5.515963e+07
# 35     36  5.341221e+07
# 4       5  4.547569e+07
# 43     44  4.329309e+07
# 32     33  3.716022e+07

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear una columna 'Month' a partir de la columna 'Date'
df_walmart['Month'] = df_walmart['Date'].dt.to_period('M')

# Gráfico de dispersión de las ventas semanales vs Temperature
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_walmart, x="Temperature", y="Weekly_Sales", alpha=0.5)
plt.title("Comparación de Ventas Semanales con Temperature")
plt.xlabel("Temperature")
plt.ylabel("Ventas Semanales")
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear una columna 'Month' a partir de la columna 'Date'
df_walmart['Month'] = df_walmart['Date'].dt.to_period('M')

# Gráfico de dispersión de las ventas semanales vs Unemployment
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_walmart, x="Unemployment", y="Weekly_Sales", alpha=0.5)
plt.title("Comparación de Ventas Semanales con Unemployment")
plt.xlabel("Unemployment")
plt.ylabel("Ventas Semanales")
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Convertir la columna 'Date' a datetime con el formato correcto
df_walmart['Date'] = pd.to_datetime(df_walmart['Date'], format='%d-%m-%Y')

# Crear una columna 'Month' a partir de la columna 'Date'
df_walmart['Month'] = df_walmart['Date'].dt.to_period('M')

# Gráfico de caja de las ventas semanales vs Holiday_Flag
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_walmart, x="Holiday_Flag", y="Weekly_Sales")
plt.title("Comparación de Ventas Semanales con Holiday Flag")
plt.xlabel("Holiday Flag")
plt.ylabel("Ventas Semanales")
plt.show()

# %%
df_walmart['Month'] = df_walmart['Date'].dt.month
df_walmart.drop(columns=['Date'], inplace=True)

# %%
df_walmart
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0     5.727778       2.572  211.096358
# 1         1    1641957.44             1     3.616667       2.548  211.242170
# 2         1    1611968.17             0     4.405556       2.514  211.289143
# 3         1    1409727.59             0     8.127778       2.561  211.319643
# 4         1    1554806.68             0     8.055556       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0    18.266667       3.997  192.013558
# 6431     45     733455.07             0    18.272222       3.985  192.170412
# 6432     45     734464.36             0    12.483333       4.000  192.327265
# 6433     45     718125.53             0    13.594444       3.969  192.330854
# 6434     45     760281.43             0    14.916667       3.882  192.308899
#
#       Unemployment  Year  Month  Day
# 0            8.106  2010      2    5
# 1            8.106  2010      2   12
# 2            8.106  2010      2   19
# 3            8.106  2010      2   26
# 4            8.106  2010      3    5
# ...            ...   ...    ...  ...
# 6430         8.684  2012      9   28
# 6431         8.667  2012     10    5
# 6432         8.667  2012     10   12
# 6433         8.667  2012     10   19
# 6434         8.667  2012     10   26
#
# [6435 rows x 10 columns]

# %%
# Separar características y variable objetivo
X = df_walmart.drop(['Weekly_Sales'], axis=1)
y = df_walmart['Weekly_Sales']

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6)

# %%
# Escalar las características
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Escalar la variable objetivo
scaler_y = MinMaxScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
# Fijar la semilla para reproducibilidad
np.random.seed(6)
tf.random.set_seed(6)

# %%
# Definir el modelo de red neuronal
def build_model():
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Entrenar y evaluar modelos
model = build_model()
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# /home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1400586895360.0000 - val_loss: 1381635194880.0000
# Epoch 2/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 1330774933504.0000 - val_loss: 1171463471104.0000
# Epoch 3/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 1060797743104.0000 - val_loss: 752928358400.0000
# Epoch 4/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - loss: 636284108800.0000 - val_loss: 412523495424.0000
# Epoch 5/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 364154257408.0000 - val_loss: 326435471360.0000
# Epoch 6/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 311255859200.0000 - val_loss: 321076789248.0000
# Epoch 7/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 308675641344.0000 - val_loss: 320749469696.0000
# Epoch 8/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 308461207552.0000 - val_loss: 320542081024.0000
# Epoch 9/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 308265746432.0000 - val_loss: 320335642624.0000
# Epoch 10/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 308064583680.0000 - val_loss: 320126058496.0000
# Epoch 11/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 307859292160.0000 - val_loss: 319913558016.0000
# Epoch 12/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 307650560000.0000 - val_loss: 319698436096.0000
# Epoch 13/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 307438944256.0000 - val_loss: 319481282560.0000
# Epoch 14/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 307224870912.0000 - val_loss: 319262195712.0000
# Epoch 15/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 307008536576.0000 - val_loss: 319041568768.0000
# Epoch 16/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 306790236160.0000 - val_loss: 318819532800.0000
# Epoch 17/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 306570297344.0000 - val_loss: 318596153344.0000
# Epoch 18/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 306348851200.0000 - val_loss: 318371594240.0000
# Epoch 19/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 306125963264.0000 - val_loss: 318146117632.0000
# Epoch 20/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 305901895680.0000 - val_loss: 317919526912.0000
# Epoch 21/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 305676582912.0000 - val_loss: 317692084224.0000
# Epoch 22/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 305450254336.0000 - val_loss: 317463822336.0000
# Epoch 23/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 305222975488.0000 - val_loss: 317234741248.0000
# Epoch 24/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 304994680832.0000 - val_loss: 317004906496.0000
# Epoch 25/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 304765566976.0000 - val_loss: 316774219776.0000
# Epoch 26/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 304535535616.0000 - val_loss: 316542877696.0000
# Epoch 27/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 304304652288.0000 - val_loss: 316310683648.0000
# Epoch 28/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 304072916992.0000 - val_loss: 316077867008.0000
# Epoch 29/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 303840329728.0000 - val_loss: 315844100096.0000
# Epoch 30/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 303606923264.0000 - val_loss: 315609579520.0000
# Epoch 31/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 303372632064.0000 - val_loss: 315374239744.0000
# Epoch 32/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 303137423360.0000 - val_loss: 315138146304.0000
# Epoch 33/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 302901428224.0000 - val_loss: 314900971520.0000
# Epoch 34/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 302664417280.0000 - val_loss: 314663043072.0000
# Epoch 35/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 302426521600.0000 - val_loss: 314424131584.0000
# Epoch 36/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 302187610112.0000 - val_loss: 314184138752.0000
# Epoch 37/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 301947584512.0000 - val_loss: 313943261184.0000
# Epoch 38/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 301706608640.0000 - val_loss: 313701203968.0000
# Epoch 39/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 301464485888.0000 - val_loss: 313458032640.0000
# Epoch 40/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 301221216256.0000 - val_loss: 313213779968.0000
# Epoch 41/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 300976766976.0000 - val_loss: 312968249344.0000
# Epoch 42/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 300731072512.0000 - val_loss: 312721440768.0000
# Epoch 43/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 300484132864.0000 - val_loss: 312473288704.0000
# Epoch 44/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 300235751424.0000 - val_loss: 312223825920.0000
# Epoch 45/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 299986124800.0000 - val_loss: 311972888576.0000
# Epoch 46/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 299734925312.0000 - val_loss: 311720542208.0000
# Epoch 47/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 299482316800.0000 - val_loss: 311466557440.0000
# Epoch 48/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 299228069888.0000 - val_loss: 311211032576.0000
# Epoch 49/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 298972315648.0000 - val_loss: 310953836544.0000
# Epoch 50/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 298714824704.0000 - val_loss: 310694903808.0000
# Epoch 51/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 298455629824.0000 - val_loss: 310434299904.0000
# Epoch 52/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 298194665472.0000 - val_loss: 310171795456.0000
# Epoch 53/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 297931800576.0000 - val_loss: 309907390464.0000
# Epoch 54/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 297667100672.0000 - val_loss: 309641052160.0000
# Epoch 55/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 297400336384.0000 - val_loss: 309372616704.0000
# Epoch 56/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 297131671552.0000 - val_loss: 309102116864.0000
# Epoch 57/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 296860778496.0000 - val_loss: 308829519872.0000
# Epoch 58/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 296587821056.0000 - val_loss: 308554629120.0000
# Epoch 59/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - loss: 296312537088.0000 - val_loss: 308277477376.0000
# Epoch 60/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 296034992128.0000 - val_loss: 307997966336.0000
# Epoch 61/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 295755153408.0000 - val_loss: 307716063232.0000
# Epoch 62/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 295472726016.0000 - val_loss: 307431571456.0000
# Epoch 63/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 295187972096.0000 - val_loss: 307144589312.0000
# Epoch 64/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 294900531200.0000 - val_loss: 306854952960.0000
# Epoch 65/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 294610501632.0000 - val_loss: 306562629632.0000
# Epoch 66/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 294317752320.0000 - val_loss: 306267455488.0000
# Epoch 67/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 294022184960.0000 - val_loss: 305969430528.0000
# Epoch 68/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 293723832320.0000 - val_loss: 305668587520.0000
# Epoch 69/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 293422497792.0000 - val_loss: 305364729856.0000
# Epoch 70/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 293118115840.0000 - val_loss: 305057628160.0000
# Epoch 71/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 292810719232.0000 - val_loss: 304747577344.0000
# Epoch 72/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 292500176896.0000 - val_loss: 304434184192.0000
# Epoch 73/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 292186423296.0000 - val_loss: 304117547008.0000
# Epoch 74/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 291869392896.0000 - val_loss: 303797567488.0000
# Epoch 75/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 291548954624.0000 - val_loss: 303474049024.0000
# Epoch 76/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 291225108480.0000 - val_loss: 303147188224.0000
# Epoch 77/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 290897854464.0000 - val_loss: 302816657408.0000
# Epoch 78/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 290566930432.0000 - val_loss: 302482522112.0000
# Epoch 79/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 290232467456.0000 - val_loss: 302144618496.0000
# Epoch 80/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 289894268928.0000 - val_loss: 301802946560.0000
# Epoch 81/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 289552302080.0000 - val_loss: 301457473536.0000
# Epoch 82/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 289206566912.0000 - val_loss: 301108199424.0000
# Epoch 83/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 288856899584.0000 - val_loss: 300754894848.0000
# Epoch 84/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 288503431168.0000 - val_loss: 300397592576.0000
# Epoch 85/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 288145833984.0000 - val_loss: 300036227072.0000
# Epoch 86/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 287784271872.0000 - val_loss: 299670732800.0000
# Epoch 87/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 287418712064.0000 - val_loss: 299301175296.0000
# Epoch 88/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 287048990720.0000 - val_loss: 298927456256.0000
# Epoch 89/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 286675173376.0000 - val_loss: 298549477376.0000
# Epoch 90/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 286297227264.0000 - val_loss: 298167304192.0000
# Epoch 91/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 285915054080.0000 - val_loss: 297780903936.0000
# Epoch 92/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 285528686592.0000 - val_loss: 297390178304.0000
# Epoch 93/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 285138223104.0000 - val_loss: 296995291136.0000
# Epoch 94/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 284743434240.0000 - val_loss: 296596144128.0000
# Epoch 95/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 284344582144.0000 - val_loss: 296192835584.0000
# Epoch 96/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 283941601280.0000 - val_loss: 295785234432.0000
# Epoch 97/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 283534491648.0000 - val_loss: 295373602816.0000
# Epoch 98/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 283123384320.0000 - val_loss: 294957809664.0000
# Epoch 99/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 282708279296.0000 - val_loss: 294538018816.0000
# Epoch 100/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 282289274880.0000 - val_loss: 294114361344.0000

# %%
# Evaluar el modelo sin escalar las características
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'MSE sin escalar características: {mse}')
print(f'RMSE sin escalar características: {rmse}')
print(f'MAE sin escalar características: {mae}')
print(f'R2 sin escalar características: {r2}')
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step
# MSE sin escalar características: 296586047637.3495
# RMSE sin escalar características: 544597.1425166951
# MAE sin escalar características: 466853.4434265735
# R2 sin escalar características: 0.07324875873105852

# %%
# Evaluar el modelo con características escaladas
model_scaled = build_model()
model_scaled.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2)
y_pred_scaled = model_scaled.predict(X_test_scaled)
mse_scaled = mean_squared_error(y_test, y_pred_scaled)
rmse_scaled = np.sqrt(mse_scaled)
mae_scaled = mean_absolute_error(y_test, y_pred_scaled)
r2_scaled = r2_score(y_test, y_pred_scaled)
print(f'MSE con características escaladas: {mse_scaled}')
print(f'RMSE con características escaladas: {rmse_scaled}')
print(f'MAE con características escaladas: {mae_scaled}')
print(f'R2 con características escaladas: {r2_scaled}')
# Out:
# Epoch 1/100
# /home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1405961240576.0000 - val_loss: 1420822183936.0000
# Epoch 2/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 1405865164800.0000 - val_loss: 1420488998912.0000
# Epoch 3/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 1405393305600.0000 - val_loss: 1419503206400.0000
# Epoch 4/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 1404181282816.0000 - val_loss: 1417537650688.0000
# Epoch 5/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 1401913868288.0000 - val_loss: 1414314983424.0000
# Epoch 6/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 1398324461568.0000 - val_loss: 1409603862528.0000
# Epoch 7/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - loss: 1393191550976.0000 - val_loss: 1403213316096.0000
# Epoch 8/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 1386334650368.0000 - val_loss: 1394992349184.0000
# Epoch 9/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 1377608794112.0000 - val_loss: 1384821030912.0000
# Epoch 10/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 1366903357440.0000 - val_loss: 1372613509120.0000
# Epoch 11/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 1354139959296.0000 - val_loss: 1358311981056.0000
# Epoch 12/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 1339269447680.0000 - val_loss: 1341889708032.0000
# Epoch 13/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 1322271768576.0000 - val_loss: 1323344330752.0000
# Epoch 14/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 1303152427008.0000 - val_loss: 1302698524672.0000
# Epoch 15/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 1281942224896.0000 - val_loss: 1280000917504.0000
# Epoch 16/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 1258695819264.0000 - val_loss: 1255319273472.0000
# Epoch 17/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 1233487790080.0000 - val_loss: 1228742983680.0000
# Epoch 18/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 1206415261696.0000 - val_loss: 1200379527168.0000
# Epoch 19/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 1177591218176.0000 - val_loss: 1170353946624.0000
# Epoch 20/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 1147147780096.0000 - val_loss: 1138807275520.0000
# Epoch 21/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 1115231354880.0000 - val_loss: 1105895227392.0000
# Epoch 22/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 1082004013056.0000 - val_loss: 1071785312256.0000
# Epoch 23/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 1047637917696.0000 - val_loss: 1036656902144.0000
# Epoch 24/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 1012317683712.0000 - val_loss: 1000698478592.0000
# Epoch 25/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 976236511232.0000 - val_loss: 964105928704.0000
# Epoch 26/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - loss: 939594285056.0000 - val_loss: 927083528192.0000
# Epoch 27/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 902596722688.0000 - val_loss: 889835487232.0000
# Epoch 28/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 865451507712.0000 - val_loss: 852570406912.0000
# Epoch 29/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 828368355328.0000 - val_loss: 815497478144.0000
# Epoch 30/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 791558422528.0000 - val_loss: 778823663616.0000
# Epoch 31/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 755226640384.0000 - val_loss: 742750552064.0000
# Epoch 32/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 719573090304.0000 - val_loss: 707473047552.0000
# Epoch 33/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 684789399552.0000 - val_loss: 673176616960.0000
# Epoch 34/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 651057233920.0000 - val_loss: 640035061760.0000
# Epoch 35/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 618545545216.0000 - val_loss: 608209141760.0000
# Epoch 36/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 587407032320.0000 - val_loss: 577841725440.0000
# Epoch 37/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 557777813504.0000 - val_loss: 549056184320.0000
# Epoch 38/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 529771560960.0000 - val_loss: 521954426880.0000
# Epoch 39/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 503483924480.0000 - val_loss: 496621092864.0000
# Epoch 40/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 478985453568.0000 - val_loss: 473112608768.0000
# Epoch 41/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 456320811008.0000 - val_loss: 451460890624.0000
# Epoch 42/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 435509460992.0000 - val_loss: 431671607296.0000
# Epoch 43/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 416543211520.0000 - val_loss: 413725392896.0000
# Epoch 44/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - loss: 399390801920.0000 - val_loss: 397581352960.0000
# Epoch 45/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 384003244032.0000 - val_loss: 383176343552.0000
# Epoch 46/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 370307039232.0000 - val_loss: 370425298944.0000
# Epoch 47/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 358214500352.0000 - val_loss: 359228080128.0000
# Epoch 48/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 347619753984.0000 - val_loss: 349477535744.0000
# Epoch 49/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 338410045440.0000 - val_loss: 341053669376.0000
# Epoch 50/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 330466033664.0000 - val_loss: 333834518528.0000
# Epoch 51/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 323663134720.0000 - val_loss: 327694352384.0000
# Epoch 52/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 317869817856.0000 - val_loss: 322506260480.0000
# Epoch 53/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 312959696896.0000 - val_loss: 318148476928.0000
# Epoch 54/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 308817887232.0000 - val_loss: 314501398528.0000
# Epoch 55/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 305334190080.0000 - val_loss: 311456563200.0000
# Epoch 56/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 302404927488.0000 - val_loss: 308915929088.0000
# Epoch 57/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 299932221440.0000 - val_loss: 306792824832.0000
# Epoch 58/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 297834250240.0000 - val_loss: 305007296512.0000
# Epoch 59/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 296041447424.0000 - val_loss: 303495610368.0000
# Epoch 60/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 294496600064.0000 - val_loss: 302206320640.0000
# Epoch 61/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 293152555008.0000 - val_loss: 301091684352.0000
# Epoch 62/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 291972743168.0000 - val_loss: 300117000192.0000
# Epoch 63/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 290923511808.0000 - val_loss: 299251204096.0000
# Epoch 64/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 289978515456.0000 - val_loss: 298472407040.0000
# Epoch 65/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 289118093312.0000 - val_loss: 297763110912.0000
# Epoch 66/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 288326025216.0000 - val_loss: 297110110208.0000
# Epoch 67/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 287589990400.0000 - val_loss: 296501477376.0000
# Epoch 68/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 286899535872.0000 - val_loss: 295925809152.0000
# Epoch 69/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 286247419904.0000 - val_loss: 295379402752.0000
# Epoch 70/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 285629087744.0000 - val_loss: 294859374592.0000
# Epoch 71/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 285042114560.0000 - val_loss: 294360743936.0000
# Epoch 72/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 284481945600.0000 - val_loss: 293881020416.0000
# Epoch 73/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 283945369600.0000 - val_loss: 293415649280.0000
# Epoch 74/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 283428978688.0000 - val_loss: 292964270080.0000
# Epoch 75/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 282932346880.0000 - val_loss: 292525572096.0000
# Epoch 76/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 282453737472.0000 - val_loss: 292097556480.0000
# Epoch 77/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 281989185536.0000 - val_loss: 291680124928.0000
# Epoch 78/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 281538658304.0000 - val_loss: 291271278592.0000
# Epoch 79/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 281100517376.0000 - val_loss: 290871181312.0000
# Epoch 80/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 280674664448.0000 - val_loss: 290480226304.0000
# Epoch 81/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 280260444160.0000 - val_loss: 290097037312.0000
# Epoch 82/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 279856611328.0000 - val_loss: 289720565760.0000
# Epoch 83/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 279463067648.0000 - val_loss: 289352515584.0000
# Epoch 84/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 279077388288.0000 - val_loss: 288988004352.0000
# Epoch 85/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 278699180032.0000 - val_loss: 288630046720.0000
# Epoch 86/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 278330474496.0000 - val_loss: 288276807680.0000
# Epoch 87/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 277970124800.0000 - val_loss: 287930155008.0000
# Epoch 88/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 277617541120.0000 - val_loss: 287589728256.0000
# Epoch 89/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 277271707648.0000 - val_loss: 287255199744.0000
# Epoch 90/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 276933378048.0000 - val_loss: 286924668928.0000
# Epoch 91/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 276602060800.0000 - val_loss: 286601641984.0000
# Epoch 92/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 276278312960.0000 - val_loss: 286285529088.0000
# Epoch 93/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 275959644160.0000 - val_loss: 285973643264.0000
# Epoch 94/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 275645005824.0000 - val_loss: 285667033088.0000
# Epoch 95/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 275336232960.0000 - val_loss: 285365534720.0000
# Epoch 96/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 275033325568.0000 - val_loss: 285068328960.0000
# Epoch 97/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 274736005120.0000 - val_loss: 284775677952.0000
# Epoch 98/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 274445041664.0000 - val_loss: 284488368128.0000
# Epoch 99/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 274160074752.0000 - val_loss: 284206039040.0000
# Epoch 100/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 273881432064.0000 - val_loss: 283929804800.0000
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# MSE con características escaladas: 294695800883.7309
# RMSE con características escaladas: 542858.9143449068
# MAE con características escaladas: 454582.05479506607
# R2 con características escaladas: 0.07915526896367286

# %%
# Evaluar el modelo con salida escalada
model_output_scaled = build_model()
model_output_scaled.fit(X_train_scaled, y_train_scaled, epochs=100, batch_size=32, validation_split=0.2)
y_pred_output_scaled = model_output_scaled.predict(X_test_scaled)
y_pred_output = scaler_y.inverse_transform(y_pred_output_scaled)
mse_output_scaled = mean_squared_error(y_test, y_pred_output)
rmse_output_scaled = np.sqrt(mse_output_scaled)
mae_output_scaled = mean_absolute_error(y_test, y_pred_output)
r2_output_scaled = r2_score(y_test, y_pred_output)
print(f'MSE con salida escalada: {mse_output_scaled}')
print(f'RMSE con salida escalada: {rmse_output_scaled}')
print(f'MAE con salida escalada: {mae_output_scaled}')
print(f'R2 con salida escalada: {r2_output_scaled}')
# Out:
# Epoch 1/100
# /home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0962 - val_loss: 0.0238
# Epoch 2/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 3/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - loss: 0.0191 - val_loss: 0.0200
# Epoch 4/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.0177 - val_loss: 0.0192
# Epoch 5/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.0169 - val_loss: 0.0185
# Epoch 6/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.0162 - val_loss: 0.0180
# Epoch 7/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.0157 - val_loss: 0.0175
# Epoch 8/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.0153 - val_loss: 0.0172
# Epoch 9/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0149 - val_loss: 0.0169
# Epoch 10/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.0146 - val_loss: 0.0167
# Epoch 11/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.0142 - val_loss: 0.0164
# Epoch 12/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.0140 - val_loss: 0.0162
# Epoch 13/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.0137 - val_loss: 0.0160
# Epoch 14/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - loss: 0.0135 - val_loss: 0.0159
# Epoch 15/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.0133 - val_loss: 0.0158
# Epoch 16/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.0131 - val_loss: 0.0156
# Epoch 17/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.0129 - val_loss: 0.0155
# Epoch 18/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.0127 - val_loss: 0.0154
# Epoch 19/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.0125 - val_loss: 0.0153
# Epoch 20/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0124 - val_loss: 0.0152
# Epoch 21/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.0121 - val_loss: 0.0151
# Epoch 22/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.0120 - val_loss: 0.0149
# Epoch 23/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.0119 - val_loss: 0.0149
# Epoch 24/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 25/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.0116 - val_loss: 0.0148
# Epoch 26/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.0114 - val_loss: 0.0147
# Epoch 27/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0113 - val_loss: 0.0147
# Epoch 28/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0112 - val_loss: 0.0147
# Epoch 29/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0111 - val_loss: 0.0146
# Epoch 30/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.0110 - val_loss: 0.0146
# Epoch 31/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.0109 - val_loss: 0.0146
# Epoch 32/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - loss: 0.0108 - val_loss: 0.0144
# Epoch 33/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.0108 - val_loss: 0.0143
# Epoch 34/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.0107 - val_loss: 0.0143
# Epoch 35/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.0106 - val_loss: 0.0144
# Epoch 36/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0105 - val_loss: 0.0143
# Epoch 37/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0105 - val_loss: 0.0142
# Epoch 38/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - loss: 0.0104 - val_loss: 0.0143
# Epoch 39/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.0103 - val_loss: 0.0142
# Epoch 40/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.0102 - val_loss: 0.0141
# Epoch 41/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.0102 - val_loss: 0.0141
# Epoch 42/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0101 - val_loss: 0.0141
# Epoch 43/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.0101 - val_loss: 0.0141
# Epoch 44/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.0100 - val_loss: 0.0140
# Epoch 45/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.0099 - val_loss: 0.0139
# Epoch 46/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - loss: 0.0099 - val_loss: 0.0139
# Epoch 47/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.0098 - val_loss: 0.0139
# Epoch 48/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0097 - val_loss: 0.0138
# Epoch 49/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - loss: 0.0097 - val_loss: 0.0138
# Epoch 50/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0096 - val_loss: 0.0137
# Epoch 51/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.0096 - val_loss: 0.0136
# Epoch 52/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.0095 - val_loss: 0.0135
# Epoch 53/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.0094 - val_loss: 0.0135
# Epoch 54/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 55/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.0093 - val_loss: 0.0133
# Epoch 56/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0093 - val_loss: 0.0132
# Epoch 57/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.0092 - val_loss: 0.0131
# Epoch 58/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0092 - val_loss: 0.0130
# Epoch 59/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 0.0091 - val_loss: 0.0130
# Epoch 60/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.0090 - val_loss: 0.0130
# Epoch 61/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0090 - val_loss: 0.0130
# Epoch 62/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 0.0089 - val_loss: 0.0129
# Epoch 63/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.0089 - val_loss: 0.0130
# Epoch 64/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.0088 - val_loss: 0.0129
# Epoch 65/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.0088 - val_loss: 0.0128
# Epoch 66/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.0087 - val_loss: 0.0128
# Epoch 67/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.0087 - val_loss: 0.0129
# Epoch 68/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - loss: 0.0087 - val_loss: 0.0128
# Epoch 69/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.0086 - val_loss: 0.0127
# Epoch 70/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - loss: 0.0086 - val_loss: 0.0127
# Epoch 71/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0085 - val_loss: 0.0126
# Epoch 72/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.0085 - val_loss: 0.0125
# Epoch 73/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.0084 - val_loss: 0.0125
# Epoch 74/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.0084 - val_loss: 0.0126
# Epoch 75/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.0084 - val_loss: 0.0125
# Epoch 76/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.0083 - val_loss: 0.0126
# Epoch 77/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.0083 - val_loss: 0.0126
# Epoch 78/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.0083 - val_loss: 0.0125
# Epoch 79/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.0082 - val_loss: 0.0124
# Epoch 80/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - loss: 0.0082 - val_loss: 0.0125
# Epoch 81/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.0081 - val_loss: 0.0124
# Epoch 82/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0081 - val_loss: 0.0125
# Epoch 83/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.0081 - val_loss: 0.0124
# Epoch 84/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 0.0080 - val_loss: 0.0124
# Epoch 85/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.0080 - val_loss: 0.0124
# Epoch 86/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.0080 - val_loss: 0.0125
# Epoch 87/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0079 - val_loss: 0.0124
# Epoch 88/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.0079 - val_loss: 0.0123
# Epoch 89/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.0079 - val_loss: 0.0123
# Epoch 90/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.0078 - val_loss: 0.0123
# Epoch 91/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.0078 - val_loss: 0.0124
# Epoch 92/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.0078 - val_loss: 0.0124
# Epoch 93/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.0078 - val_loss: 0.0123
# Epoch 94/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 95/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 96/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.0077 - val_loss: 0.0124
# Epoch 97/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0077 - val_loss: 0.0125
# Epoch 98/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.0076 - val_loss: 0.0124
# Epoch 99/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.0076 - val_loss: 0.0124
# Epoch 100/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.0076 - val_loss: 0.0125
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# MSE con salida escalada: 179839391750.04248
# RMSE con salida escalada: 424074.74783349514
# MAE con salida escalada: 328629.19381558977
# R2 con salida escalada: 0.4380505055409937

# %%
def build_model_optimizado(hp):
    model = Sequential()

    # Definir número de capas
    for i in range(hp.Int('num_layers', 2, 10)):  # Probar entre 2 y 5 capas
        model.add(Dense(units=hp.Int(f'units_{i}', min_value=16, max_value=64, step=16),
                        activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid'])))

    model.add(Dense(1, activation='sigmoid'))  # Capa de salida

    # Definir el optimizador con el learning rate como hiperparámetro
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')),
                  loss='mean_squared_error',
                  metrics=['accuracy','mean_absolute_error'])
    return model

# %%
# Optimización de hiperparámetros
tuner = kt.GridSearch(
    build_model_optimizado,  # La función que crea el modelo
    objective='val_mean_absolute_error',  # La métrica que se optimiza
    max_trials=100,  # Número máximo de combinaciones de hiperparámetros
    executions_per_trial=1,  # Número de veces que se ejecutará cada prueba
    directory='my_dir',  # Directorio para guardar los resultados
    project_name='classWallmart_grid'  # Nombre del proyecto
)

# %%
# Ejecutar la búsqueda
tuner.search(X_train_scaled, y_train_scaled, epochs=50, validation_data=(X_test_scaled, y_test_scaled))
# Out:
# Trial 2 Complete [00h 00m 09s]
#
# Best val_mean_absolute_error So Far: None
# Total elapsed time: 00h 00m 18s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |num_layers
# 16                |16                |units_0
# relu              |relu              |activation
# 16                |16                |units_1
# 0.00031623        |0.0001            |learning_rate
#
# Epoch 1/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 1.0663e-04 - loss: 0.1008 - val_accuracy: 0.0000e+00 - val_loss: 0.0422
# Epoch 2/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 1.8126e-04 - loss: 0.0357 - val_accuracy: 0.0000e+00 - val_loss: 0.0292
# Epoch 3/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 1.8126e-04 - loss: 0.0268 - val_accuracy: 0.0000e+00 - val_loss: 0.0260
# Epoch 4/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 1.8126e-04 - loss: 0.0241 - val_accuracy: 0.0000e+00 - val_loss: 0.0244
# Epoch 5/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 1.8126e-04 - loss: 0.0226 - val_accuracy: 0.0000e+00 - val_loss: 0.0235
# Epoch 6/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 1.8126e-04 - loss: 0.0216 - val_accuracy: 0.0000e+00 - val_loss: 0.0227
# Epoch 7/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.8126e-04 - loss: 0.0208 - val_accuracy: 0.0000e+00 - val_loss: 0.0222
# Epoch 8/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.8126e-04 - loss: 0.0202 - val_accuracy: 0.0000e+00 - val_loss: 0.0217
# Epoch 9/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 1.8126e-04 - loss: 0.0197 - val_accuracy: 0.0000e+00 - val_loss: 0.0213
# Epoch 10/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 1.8126e-04 - loss: 0.0193 - val_accuracy: 0.0000e+00 - val_loss: 0.0209
# Epoch 11/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 1.8126e-04 - loss: 0.0189 - val_accuracy: 0.0000e+00 - val_loss: 0.0206
# Epoch 12/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 1.8126e-04 - loss: 0.0186 - val_accuracy: 0.0000e+00 - val_loss: 0.0203
# Epoch 13/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.8126e-04 - loss: 0.0183 - val_accuracy: 0.0000e+00 - val_loss: 0.0201
# Epoch 14/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 1.8126e-04 - loss: 0.0181 - val_accuracy: 0.0000e+00 - val_loss: 0.0198
# Epoch 15/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 1.8126e-04 - loss: 0.0179 - val_accuracy: 0.0000e+00 - val_loss: 0.0196
# Epoch 16/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 1.8126e-04 - loss: 0.0177 - val_accuracy: 0.0000e+00 - val_loss: 0.0194
# Epoch 17/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 1.8126e-04 - loss: 0.0175 - val_accuracy: 0.0000e+00 - val_loss: 0.0193
# Epoch 18/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 1.8126e-04 - loss: 0.0174 - val_accuracy: 0.0000e+00 - val_loss: 0.0191
# Epoch 19/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.8126e-04 - loss: 0.0172 - val_accuracy: 0.0000e+00 - val_loss: 0.0190
# Epoch 20/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 1.8126e-04 - loss: 0.0171 - val_accuracy: 0.0000e+00 - val_loss: 0.0188
# Epoch 21/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 1.8126e-04 - loss: 0.0170 - val_accuracy: 0.0000e+00 - val_loss: 0.0187
# Epoch 22/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 1.8126e-04 - loss: 0.0168 - val_accuracy: 0.0000e+00 - val_loss: 0.0185
# Epoch 23/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 1.8126e-04 - loss: 0.0167 - val_accuracy: 0.0000e+00 - val_loss: 0.0184
# Epoch 24/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 1.8126e-04 - loss: 0.0166 - val_accuracy: 0.0000e+00 - val_loss: 0.0183
# Epoch 25/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 1.8126e-04 - loss: 0.0165 - val_accuracy: 0.0000e+00 - val_loss: 0.0182
# Epoch 26/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - accuracy: 1.8126e-04 - loss: 0.0164 - val_accuracy: 0.0000e+00 - val_loss: 0.0181
# Epoch 27/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 1.8126e-04 - loss: 0.0163 - val_accuracy: 0.0000e+00 - val_loss: 0.0180
# Epoch 28/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 1.8126e-04 - loss: 0.0162 - val_accuracy: 0.0000e+00 - val_loss: 0.0179
# Epoch 29/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 1.8126e-04 - loss: 0.0161 - val_accuracy: 0.0000e+00 - val_loss: 0.0178
# Epoch 30/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 1.8126e-04 - loss: 0.0160 - val_accuracy: 0.0000e+00 - val_loss: 0.0177
# Epoch 31/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 1.8126e-04 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0176
# Epoch 32/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 1.8126e-04 - loss: 0.0159 - val_accuracy: 0.0000e+00 - val_loss: 0.0175
# Epoch 33/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 1.8126e-04 - loss: 0.0158 - val_accuracy: 0.0000e+00 - val_loss: 0.0174
# Epoch 34/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 1.8126e-04 - loss: 0.0157 - val_accuracy: 0.0000e+00 - val_loss: 0.0173
# Epoch 35/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 1.8126e-04 - loss: 0.0156 - val_accuracy: 0.0000e+00 - val_loss: 0.0172
# Epoch 36/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 1.8126e-04 - loss: 0.0155 - val_accuracy: 0.0000e+00 - val_loss: 0.0171
# Epoch 37/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 1.8126e-04 - loss: 0.0155 - val_accuracy: 0.0000e+00 - val_loss: 0.0170
# Epoch 38/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 1.8126e-04 - loss: 0.0154 - val_accuracy: 0.0000e+00 - val_loss: 0.0169
# Epoch 39/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 1.8126e-04 - loss: 0.0153 - val_accuracy: 0.0000e+00 - val_loss: 0.0168
# Epoch 40/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 1.8126e-04 - loss: 0.0153 - val_accuracy: 0.0000e+00 - val_loss: 0.0167
# Epoch 41/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 1.8126e-04 - loss: 0.0152 - val_accuracy: 0.0000e+00 - val_loss: 0.0167
# Epoch 42/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 1.8126e-04 - loss: 0.0151 - val_accuracy: 0.0000e+00 - val_loss: 0.0166
# Epoch 43/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 1.8126e-04 - loss: 0.0151 - val_accuracy: 0.0000e+00 - val_loss: 0.0165
# Epoch 44/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 1.8126e-04 - loss: 0.0150 - val_accuracy: 0.0000e+00 - val_loss: 0.0165
# Epoch 45/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 1.8126e-04 - loss: 0.0150 - val_accuracy: 0.0000e+00 - val_loss: 0.0164
# Epoch 46/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 1.8126e-04 - loss: 0.0149 - val_accuracy: 0.0000e+00 - val_loss: 0.0163
# Epoch 47/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 1.8126e-04 - loss: 0.0148 - val_accuracy: 0.0000e+00 - val_loss: 0.0163
# Epoch 48/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 1.8126e-04 - loss: 0.0148 - val_accuracy: 0.0000e+00 - val_loss: 0.0162
# Epoch 49/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 1.8126e-04 - loss: 0.0147 - val_accuracy: 0.0000e+00 - val_loss: 0.0161
# Epoch 50/50
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 1.8126e-04 - loss: 0.0147 - val_accuracy: 0.0000e+00 - val_loss: 0.0161
# Traceback (most recent call last):
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py", line 265, in _run_and_update_trial
#     tuner_utils.convert_to_metrics_dict(
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner_utils.py", line 132, in convert_to_metrics_dict
#     [convert_to_metrics_dict(elem, objective) for elem in results]
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner_utils.py", line 145, in convert_to_metrics_dict
#     best_value, _ = _get_best_value_and_best_epoch_from_history(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner_utils.py", line 116, in _get_best_value_and_best_epoch_from_history
#     objective_value = objective.get_value(metrics)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/objective.py", line 59, in get_value
#     return logs[self.name]
#            ~~~~^^^^^^^^^^^
# KeyError: 'val_mean_absolute_error'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[314], line 2
#       1 # Ejecutar la búsqueda
# ----> 2 tuner.search(X_train_scaled, y_train_scaled, epochs=50, validation_data=(X_test_scaled, y_test_scaled))
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py:235, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     233     self.on_trial_begin(trial)
#     234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py:339, in BaseTuner.on_trial_end(self, trial)
#     333 def on_trial_end(self, trial):
#     334     """Called at the end of a trial.
#     335
#     336     Args:
#     337         trial: A `Trial` instance.
#     338     """
# --> 339     self.oracle.end_trial(trial)
#     340     self.save()
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/tuners/gridsearch.py:317, in GridSearchOracle.end_trial(self, trial)
#     315 @oracle_module.synchronized
#     316 def end_trial(self, trial):
# --> 317     super().end_trial(trial)
#     318     # It is OK for a trial_id to be pushed into _populate_next multiple
#     319     # times. It will be skipped during _populate_space if its next
#     320     # combination has been tried.
#     321
#     322     # For not blocking _populate_space, we push it regardless of the status.
#     323     self._populate_next.append(trial.trial_id)
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/oracle.py:108, in synchronized.<locals>.wrapped_func(*args, **kwargs)
#     106     LOCKS[oracle].acquire()
#     107     THREADS[oracle] = thread_name
# --> 108 ret_val = func(*args, **kwargs)
#     109 if need_acquire:
#     110     THREADS[oracle] = None
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/oracle.py:588, in Oracle.end_trial(self, trial)
#     586 if not self._retry(trial):
#     587     self.end_order.append(trial.trial_id)
# --> 588     self._check_consecutive_failures()
#     590 self._save_trial(trial)
#     591 self.save()
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/oracle.py:545, in Oracle._check_consecutive_failures(self)
#     543     consecutive_failures = 0
#     544 if consecutive_failures == self.max_consecutive_failed_trials:
# --> 545     raise RuntimeError(
#     546         "Number of consecutive failures exceeded the limit "
#     547         f"of {self.max_consecutive_failed_trials}.\n"
#     548         + (trial.message or "")
#     549     )
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.
# Traceback (most recent call last):
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py", line 265, in _run_and_update_trial
#     tuner_utils.convert_to_metrics_dict(
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner_utils.py", line 132, in convert_to_metrics_dict
#     [convert_to_metrics_dict(elem, objective) for elem in results]
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner_utils.py", line 145, in convert_to_metrics_dict
#     best_value, _ = _get_best_value_and_best_epoch_from_history(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner_utils.py", line 116, in _get_best_value_and_best_epoch_from_history
#     objective_value = objective.get_value(metrics)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alumnadotarde/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/objective.py", line 59, in get_value
#     return logs[self.name]
#            ~~~~^^^^^^^^^^^
# KeyError: 'val_mean_absolute_error'

# %%
# Obtener los mejores hiperparámetros
best_hps = tuner.get_best_hyperparameters()[0]
print(f"Mejores hiperparámetros: {best_hps.values}")

# Crear el modelo final con los mejores hiperparámetros
model_grid = tuner.hypermodel.build(best_hps)
# Out:
# Mejores hiperparámetros: {'num_layers': 2, 'units_0': 16, 'activation': 'relu', 'units_1': 16, 'learning_rate': 0.007943282347242817}

# %%
# Entrenar el modelo final
model_grid.fit(X_train_scaled, y_train_scaled, epochs=30, validation_data=(X_test_scaled, y_test_scaled))
# Out:
# Epoch 1/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5477 - val_accuracy: 0.0000e+00 - val_loss: 0.5205
# Epoch 2/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 1.8126e-04 - loss: 0.5282 - val_accuracy: 0.0000e+00 - val_loss: 0.5169
# Epoch 3/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 1.8126e-04 - loss: 0.5254 - val_accuracy: 0.0000e+00 - val_loss: 0.5142
# Epoch 4/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 1.8126e-04 - loss: 0.5225 - val_accuracy: 0.0000e+00 - val_loss: 0.5121
# Epoch 5/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 1.8126e-04 - loss: 0.5197 - val_accuracy: 0.0000e+00 - val_loss: 0.5094
# Epoch 6/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 1.8126e-04 - loss: 0.5173 - val_accuracy: 0.0000e+00 - val_loss: 0.5075
# Epoch 7/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 1.8126e-04 - loss: 0.5157 - val_accuracy: 0.0000e+00 - val_loss: 0.5055
# Epoch 8/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 1.8126e-04 - loss: 0.5137 - val_accuracy: 0.0000e+00 - val_loss: 0.5040
# Epoch 9/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 1.8126e-04 - loss: 0.5121 - val_accuracy: 0.0000e+00 - val_loss: 0.5029
# Epoch 10/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 1.8126e-04 - loss: 0.5108 - val_accuracy: 0.0000e+00 - val_loss: 0.5013
# Epoch 11/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 1.8126e-04 - loss: 0.5094 - val_accuracy: 0.0000e+00 - val_loss: 0.4998
# Epoch 12/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 1.8126e-04 - loss: 0.5084 - val_accuracy: 0.0000e+00 - val_loss: 0.4985
# Epoch 13/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 2.8789e-04 - loss: 0.5071 - val_accuracy: 0.0000e+00 - val_loss: 0.4973
# Epoch 14/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 2.8789e-04 - loss: 0.5061 - val_accuracy: 0.0000e+00 - val_loss: 0.4965
# Epoch 15/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 2.8789e-04 - loss: 0.5053 - val_accuracy: 0.0000e+00 - val_loss: 0.4956
# Epoch 16/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - accuracy: 2.8789e-04 - loss: 0.5047 - val_accuracy: 0.0000e+00 - val_loss: 0.4945
# Epoch 17/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 2.8789e-04 - loss: 0.5037 - val_accuracy: 0.0000e+00 - val_loss: 0.4932
# Epoch 18/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - accuracy: 2.8789e-04 - loss: 0.5030 - val_accuracy: 0.0000e+00 - val_loss: 0.4928
# Epoch 19/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 2.8789e-04 - loss: 0.5025 - val_accuracy: 0.0000e+00 - val_loss: 0.4929
# Epoch 20/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 2.8789e-04 - loss: 0.5018 - val_accuracy: 0.0000e+00 - val_loss: 0.4919
# Epoch 21/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 2.8789e-04 - loss: 0.5012 - val_accuracy: 0.0000e+00 - val_loss: 0.4916
# Epoch 22/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 2.8789e-04 - loss: 0.5005 - val_accuracy: 0.0000e+00 - val_loss: 0.4901
# Epoch 23/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 2.8789e-04 - loss: 0.4999 - val_accuracy: 0.0000e+00 - val_loss: 0.4894
# Epoch 24/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 2.8789e-04 - loss: 0.4991 - val_accuracy: 0.0000e+00 - val_loss: 0.4881
# Epoch 25/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 2.8789e-04 - loss: 0.4986 - val_accuracy: 0.0000e+00 - val_loss: 0.4873
# Epoch 26/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 2.8789e-04 - loss: 0.4982 - val_accuracy: 0.0000e+00 - val_loss: 0.4863
# Epoch 27/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 2.8789e-04 - loss: 0.4974 - val_accuracy: 0.0000e+00 - val_loss: 0.4861
# Epoch 28/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 2.8789e-04 - loss: 0.4969 - val_accuracy: 0.0000e+00 - val_loss: 0.4867
# Epoch 29/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 2.8789e-04 - loss: 0.4967 - val_accuracy: 0.0000e+00 - val_loss: 0.4861
# Epoch 30/30
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 2.8789e-04 - loss: 0.4964 - val_accuracy: 0.0000e+00 - val_loss: 0.4847

# %%
# Evaluar el modelo optimizado
best_model = model_grid
y_pred_optimized_scaled = best_model.predict(X_test_scaled)
y_pred_optimized = scaler_y.inverse_transform(y_pred_optimized_scaled.reshape(-1, 1))
mse_optimized = mean_squared_error(y_test, y_pred_optimized)
rmse_optimized = np.sqrt(mse_optimized)
mae_optimized = mean_absolute_error(y_test, y_pred_optimized)
r2_optimized = r2_score(y_test, y_pred_optimized)
print(f'MSE del modelo optimizado con grid: {mse_optimized}')
print(f'RMSE del modelo optimizado con grid: {rmse_optimized}')
print(f'MAE del modelo optimizado con grid: {mae_optimized}')
print(f'R2 del modelo optimizado con grid: {r2_optimized}')
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step
# MSE del modelo optimizado con grid: 85295529584.5412
# RMSE del modelo optimizado con grid: 292053.9840244286
# MAE del modelo optimizado con grid: 197514.89096493783
# R2 del modelo optimizado con grid: 0.7334745226659452

# %%
tuner_baye = kt.BayesianOptimization(
    build_model_optimizado,  # La función que crea el modelo
    objective='val_mae',  # La métrica que se optimiza
    max_trials=10,  # Número máximo de combinaciones de hiperparámetros
    executions_per_trial=1,  # Número de veces que se ejecutará cada prueba
    directory='my_dir',  # Directorio para guardar los resultados
    project_name='classWallmart_baye'  # Nombre del proyecto
)
# Out:
# Reloading Tuner from my_dir/classWallmart_baye/tuner0.json

# %%
tuner_baye.search(X_train_scaled, y_train_scaled, epochs=30, validation_data=(X_test_scaled, y_test_scaled))

# %%
# Mostrar los mejores hiperparámetros encontrados
best_hps = tuner_baye.get_best_hyperparameters(num_trials=1)[0]
print(f"Mejores hiperparámetros: {best_hps.values}")
model_baye = tuner.hypermodel.build(best_hps)
# Out:
# Mejores hiperparámetros: {'num_layers': 10, 'units_0': 16, 'activation': 'sigmoid', 'units_1': 64, 'learning_rate': 0.0035766126839820184, 'units_2': 48, 'units_3': 16, 'units_4': 16, 'units_5': 64, 'units_6': 48, 'units_7': 16, 'units_8': 48, 'units_9': 48}

# %%
model_baye.fit(X_train_scaled, y_train_scaled, epochs=100, validation_data=(X_test_scaled, y_test_scaled))
# Out:
# Epoch 1/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.8126e-04 - loss: 0.5537 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 2/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 3/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 4/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 5/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 6/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 7/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 8/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 9/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 10/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 11/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5369
# Epoch 12/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 13/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 14/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 15/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5468 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 16/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5469 - val_accuracy: 0.0000e+00 - val_loss: 0.5372
# Epoch 17/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5469 - val_accuracy: 0.0000e+00 - val_loss: 0.5373
# Epoch 18/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5469 - val_accuracy: 0.0000e+00 - val_loss: 0.5374
# Epoch 19/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5469 - val_accuracy: 0.0000e+00 - val_loss: 0.5375
# Epoch 20/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5376
# Epoch 21/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5377
# Epoch 22/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5378
# Epoch 23/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5379
# Epoch 24/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5379
# Epoch 25/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5380
# Epoch 26/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5380
# Epoch 27/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5381
# Epoch 28/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5381
# Epoch 29/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5381
# Epoch 30/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5381
# Epoch 31/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5381
# Epoch 32/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5381
# Epoch 33/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5380
# Epoch 34/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5380
# Epoch 35/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5380
# Epoch 36/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5380
# Epoch 37/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5379
# Epoch 38/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5379
# Epoch 39/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5379
# Epoch 40/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5378
# Epoch 41/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5378
# Epoch 42/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5377
# Epoch 43/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5377
# Epoch 44/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5377
# Epoch 45/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5376
# Epoch 46/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5473 - val_accuracy: 0.0000e+00 - val_loss: 0.5375
# Epoch 47/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5375
# Epoch 48/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5374
# Epoch 49/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5373
# Epoch 50/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 1.8126e-04 - loss: 0.5472 - val_accuracy: 0.0000e+00 - val_loss: 0.5372
# Epoch 51/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5372
# Epoch 52/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 53/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5471 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 54/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 55/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 56/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5371
# Epoch 57/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 58/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 59/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 60/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 61/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 62/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 63/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 64/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 65/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 66/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 67/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 68/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 69/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 70/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 71/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 72/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 73/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 74/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 75/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 76/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 77/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 78/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 79/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 80/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 81/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 82/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 83/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 84/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 85/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 86/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 87/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 88/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 89/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 90/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 91/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 92/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 93/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 94/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 95/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 96/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 97/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 98/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 99/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370
# Epoch 100/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.8126e-04 - loss: 0.5470 - val_accuracy: 0.0000e+00 - val_loss: 0.5370

# %%
# Evaluar el modelo optimizado
best_model = model_baye
y_pred_optimized_scaled_baye = best_model.predict(X_test_scaled)
y_pred_optimized_baye = scaler_y.inverse_transform(y_pred_optimized_scaled_baye.reshape(-1, 1))
mse_optimized_baye = mean_squared_error(y_test, y_pred_optimized_baye)
rmse_optimized_baye = np.sqrt(mse_optimized_baye)
mae_optimized_baye = mean_absolute_error(y_test, y_pred_optimized_baye)
r2_optimized_baye = r2_score(y_test, y_pred_optimized_baye)
print(f'MSE del modelo optimizado bayesiano: {mse_optimized_baye}')
print(f'RMSE del modelo optimizado bayesiano: {rmse_optimized_baye}')
print(f'MAE del modelo optimizado bayesiano: {mae_optimized_baye}')
print(f'R2 del modelo optimizado bayesiano: {r2_optimized_baye}')
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE del modelo optimizado bayesiano: 320667155954.28876
# RMSE del modelo optimizado bayesiano: 566274.8060388073
# MAE del modelo optimizado bayesiano: 477094.6127952602
# R2 del modelo optimizado bayesiano: -0.0019981964161492893

# %%
tuner_random = kt.RandomSearch(
    build_model_optimizado,  # La función que construye el modelo
    objective='val_mae',  # Objetivo a optimizar
    max_trials=10,  # Número máximo de pruebas
    executions_per_trial=1,  # Número de ejecuciones por prueba
    directory='my_dir',  # Directorio donde guardar los resultados
    project_name='classWallmart_baye_random'  # Nombre del proyecto
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[729], line 1
# ----> 1 tuner_random = kt.RandomSearch(
#       2     build_model,  # La función que construye el modelo
#       3     objective='val_accuracy',  # Objetivo a optimizar
#       4     max_trials=20,  # Número máximo de pruebas
#       5     executions_per_trial=1,  # Número de ejecuciones por prueba
#       6     directory='my_dir',  # Directorio donde guardar los resultados
#       7     project_name='classWallmart_baye_random'  # Nombre del proyecto
#       8 )
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/tuners/randomsearch.py:174, in RandomSearch.__init__(self, hypermodel, objective, max_trials, seed, hyperparameters, tune_new_entries, allow_new_entries, max_retries_per_trial, max_consecutive_failed_trials, **kwargs)
#     163 self.seed = seed
#     164 oracle = RandomSearchOracle(
#     165     objective=objective,
#     166     max_trials=max_trials,
#    (...)
#     172     max_consecutive_failed_trials=max_consecutive_failed_trials,
#     173 )
# --> 174 super().__init__(oracle, hypermodel, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/tuner.py:122, in Tuner.__init__(self, oracle, hypermodel, max_model_size, optimizer, loss, metrics, distribution_strategy, directory, project_name, logger, tuner_id, overwrite, executions_per_trial, **kwargs)
#     114 if hypermodel is None and self.__class__.run_trial is Tuner.run_trial:
#     115     raise ValueError(
#     116         "Received `hypermodel=None`. We only allow not specifying "
#     117         "`hypermodel` if the user defines the search space in "
#     118         "`Tuner.run_trial()` by subclassing a `Tuner` class without "
#     119         "using a `HyperModel` instance."
#     120     )
# --> 122 super().__init__(
#     123     oracle=oracle,
#     124     hypermodel=hypermodel,
#     125     directory=directory,
#     126     project_name=project_name,
#     127     logger=logger,
#     128     overwrite=overwrite,
#     129     **kwargs,
#     130 )
#     132 self.max_model_size = max_model_size
#     133 self.optimizer = optimizer
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py:132, in BaseTuner.__init__(self, oracle, hypermodel, directory, project_name, overwrite, **kwargs)
#     129     self.reload()
#     130 else:
#     131     # Only populate initial space if not reloading.
# --> 132     self._populate_initial_space()
#     134 # Run in distributed mode.
#     135 if dist_utils.has_chief_oracle() and not dist_utils.is_chief_oracle():
#     136     # Proxies requests to the chief oracle.
#     137     # Avoid import at the top, to avoid inconsistent protobuf versions.
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py:192, in BaseTuner._populate_initial_space(self)
#     190 self.hypermodel.declare_hyperparameters(hp)
#     191 self.oracle.update_space(hp)
# --> 192 self._activate_all_conditions()
#
# File ~/anaconda3/lib/python3.12/site-packages/keras_tuner/engine/base_tuner.py:149, in BaseTuner._activate_all_conditions(self)
#     147 hp = self.oracle.get_space()
#     148 while True:
# --> 149     self.hypermodel.build(hp)
#     150     self.oracle.update_space(hp)
#     152     # Update the recorded scopes.
#
# TypeError: build_model() takes 0 positional arguments but 1 was given

# %%
# Ejecutar la búsqueda
tuner.search(X_train_scaled, y_train_scaled, epochs=100, validation_data=(X_test_scaled, y_test_scaled))

# %%
# Obtener los mejores hiperparámetros
best_hps = tuner.get_best_hyperparameters()[0]
print(f"Mejores hiperparámetros: {best_hps.values}")

# Crear el modelo final con los mejores hiperparámetros
model_random = tuner.hypermodel.build(best_hps)

# %%
# Entrenar el modelo final
model_random.fit(X_train_scaled, y_train_scaled, epochs=30, validation_data=(X_test_scaled, y_test_scaled))

# %%
# Evaluar el modelo optimizado
best_model = model_random
y_pred_optimized_scaled_random = best_model.predict(X_test_scaled)
y_pred_optimized_random = scaler_y.inverse_transform(y_pred_optimized_scaled_random.reshape(-1, 1))
mse_optimized_random = mean_squared_error(y_test, y_pred_optimized_random)
rmse_optimized_random= np.sqrt(mse_optimized_random)
mae_optimized_random= mean_absolute_error(y_test, y_pred_optimized_random)
r2_optimized_random = r2_score(y_test, y_pred_optimized_random)
print(f'MSE del modelo optimizado random: {mse_optimized_random}')
print(f'RMSE del modelo optimizado random: {rmse_optimized_random}')
print(f'MAE del modelo optimizado random: {mae_optimized_random}')
print(f'R2 del modelo optimizado random: {r2_optimized_random}')

# %%
tuner_hyper = kt.Hyperband(
    build_model_optimizado,  # La función que crea el modelo
    objective='val_mae',  # La métrica que se optimiza
    max_epochs=100,  # Número máximo de épocas
    hyperband_iterations=2,  # Número de iteraciones de Hyperband
    directory='my_dir',  # Directorio para guardar los resultados
    project_name='breast_cancer_hyperband'  # Nombre del proyecto
)

# %%
# Ejecutar la búsqueda
tuner.search(X_train_scaled, y_train_scaled, epochs=30, validation_data=(X_test_scaled, y_test_scaled))

# %%
# Obtener los mejores hiperparámetros
best_hps = tuner.get_best_hyperparameters()[0]
print(f"Mejores hiperparámetros: {best_hps.values}")

# Crear el modelo final con los mejores hiperparámetros
model_hyper = tuner.hypermodel.build(best_hps)

# %%
# Entrenar el modelo final
model_hyper.fit(X_train_scaled, y_train_scaled, epochs=100, validation_data=(X_test_scaled, y_test_scaled))

# %%
# Evaluar el modelo optimizado
best_model = model_hyper
y_pred_optimized_scaled_hyper = best_model.predict(X_test_scaled)
y_pred_optimized_hyper = scaler_y.inverse_transform(y_pred_optimized_scaled_hyper.reshape(-1, 1))
mse_optimized_hyper = mean_squared_error(y_test, y_pred_optimized_hyper)
rmse_optimized_hyper= np.sqrt(mse_optimized_hyper)
mae_optimized_hyper= mean_absolute_error(y_test, y_pred_optimized_hyper)
r2_optimized_hyper = r2_score(y_test, y_pred_optimized_hyper)
print(f'MSE del modelo optimizado hyper: {mse_optimized_hyper}')
print(f'RMSE del modelo optimizado hyper: {rmse_optimized_hyper}')
print(f'MAE del modelo optimizado hyper: {mae_optimized_hyper}')
print(f'R2 del modelo optimizado hyper: {r2_optimized_hyper}')

# %%
# Conclusiones
print("\nConclusiones:")
print(f"El modelo sin escalar características tiene un MSE de {mse}, un RMSE de {rmse}, un MAE de {mae} y un R2 de {r2}.")
print(f"El modelo con características escaladas tiene un MSE de {mse_scaled}, un RMSE de {rmse_scaled}, un MAE de {mae_scaled} y un R2 de {r2_scaled}.")
print(f"El modelo con salida escalada tiene un MSE de {mse_output_scaled}, un RMSE de {rmse_output_scaled}, un MAE de {mae_output_scaled} y un R2 de {r2_output_scaled}.")
print(f"El modelo optimizado grid tiene un MSE de {mse_optimized}, un RMSE de {rmse_optimized}, un MAE de {mae_optimized} y un R2 de {r2_optimized}.")
print(f"El modelo optimizado baye tiene un MSE de {mse_optimized_baye}, un RMSE de {rmse_optimized}_baye, un MAE de {mae_optimized_baye} y un R2 de {r2_optimized_baye}.")
print(f"El modelo optimizado random tiene un MSE de {mse_optimized_random}, un RMSE de {rmse_optimized_random}, un MAE de {mae_optimized_random} y un R2 de {r2_optimized_random}.")
print(f"El modelo optimizado hyper tiene un MSE de {mse_optimized_hyper}, un RMSE de {rmse_optimized_hyper}, un MAE de {mae_optimized_hyper} y un R2 de {r2_optimized_hyper}.")
# Out:
# Conclusiones:
# El modelo sin escalar características tiene un MSE de 301607176929.986, un RMSE de 549187.7428803251, un MAE de 470275.57393745147 y un R2 de 0.05755908674010701.
# El modelo con características escaladas tiene un MSE de 318878097163.1605, un RMSE de 564692.922890982, un MAE de 462083.0527833625 y un R2 de 0.003592128781509718.
# El modelo con salida escalada tiene un MSE de 172658456359.69547, un RMSE de 415521.9083991787, un MAE de 321747.38388403266 y un R2 de 0.4604889878616911.
# El modelo optimizado tiene un MSE de 63542648064.26688, un RMSE de 252076.6710036192, un MAE de 158869.76352940462 y un R2 de 0.8014463983178319.

# %%
# Comparación de resultados
results = {
    'Modelo sin escalar características': (mse, rmse, mae, r2),
    'Modelo con características escaladas': (mse_scaled, rmse_scaled, mae_scaled, r2_scaled),
    'Modelo con salida escalada': (mse_output_scaled, rmse_output_scaled, mae_output_scaled, r2_output_scaled),
    'Modelo optimizado grid': (mse_optimized, rmse_optimized, mae_optimized, r2_optimized),
    'Modelo optimizado baye': (mse_optimized_baye, rmse_optimized_baye, mae_optimized_baye, r2_optimized_baye),
    'Modelo optimizado random': (mse_optimized_random, rmse_optimized_random, mae_optimized_random, r2_optimized_random),
    'Modelo optimizado hyper': (mse_optimized_hyper, rmse_optimized_hyper, mae_optimized_hyper, r2_optimized_hyper)
}

# Mostrar los resultados en un gráfico de barras
metrics = ['MSE', 'RMSE', 'MAE', 'R2']
for i, metric in enumerate(metrics):
    plt.figure(figsize=(10, 6))
    plt.bar(results.keys(), [result[i] for result in results.values()], color=['blue', 'green', 'red', 'purple', 'orange', 'cyan', 'magenta'])
    plt.ylabel(metric)
    plt.title(f'Comparación de {metric} entre diferentes modelos')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Gráficos de dispersión para cada modelo
def plot_predictions(y_test, y_pred, title):
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred, color="red", alpha=0.5, label="Predicciones")
    plt.scatter(y_test, y_test, color="blue", alpha=0.5, label="Valores Reales")
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="black", linestyle="--", label="Línea Perfecta")
    plt.xlabel("Valores reales")
    plt.ylabel("Predicciones")
    plt.title(title)
    plt.legend()
    plt.show()

# %%
# Gráfico para el modelo sin escalar características
plot_predictions(y_test, y_pred, "Modelo sin escalar características: Predicción vs Realidad")

# Gráfico para el modelo con características escaladas
plot_predictions(y_test, y_pred_scaled, "Modelo con características escaladas: Predicción vs Realidad")

# Gráfico para el modelo con salida escalada
plot_predictions(y_test, y_pred_output, "Modelo con salida escalada: Predicción vs Realidad")

# Gráfico para el modelo optimizado
plot_predictions(y_test, y_pred_optimized, "Modelo optimizado: Predicción vs Realidad")

# Gráfico para el modelo optimizado bayesiano
plot_predictions(y_test, y_pred_optimized_baye, "Modelo optimizado bayesiano: Predicción vs Realidad")

# Gráfico para el modelo optimizado random
plot_predictions(y_test, y_pred_optimized_random, "Modelo optimizado random: Predicción vs Realidad")

# Gráfico para el modelo optimizado hyper
plot_predictions(y_test, y_pred_optimized_hyper, "Modelo optimizado hyper: Predicción vs Realidad")
